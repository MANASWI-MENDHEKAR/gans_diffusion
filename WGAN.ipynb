# %% [markdown]
# <a href="https://colab.research.google.com/github/MANASWI-MENDHEKAR/gans_diffusion/blob/main/WGAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import torchvision.utils as vutils

# --- Configuration ---
device = "cuda" if torch.cuda.is_available() else "cpu"
LEARNING_RATE = 1e-4
BATCH_SIZE = 64
IMAGE_SIZE = 64
CHANNELS_IMG = 1
Z_DIM = 100
NUM_EPOCHS = 30  # Increased for better convergence
FEATURES_CRITIC = 64
FEATURES_GEN = 64
CRITIC_ITERATIONS = 5
LAMBDA_GP = 10  # Standard weight for Gradient Penalty

# --- 1. The Critic (Modified for GP) ---
class Critic(nn.Module):
    def __init__(self, channels_img, features_d):
        super(Critic, self).__init__()
        self.critic = nn.Sequential(
            nn.Conv2d(channels_img, features_d, 4, 2, 1),
            nn.LeakyReLU(0.2),
            # Note: We use InstanceNorm/LayerNorm instead of BatchNorm for WGAN-GP
            self._block(features_d, features_d * 2, 4, 2, 1),
            self._block(features_d * 2, features_d * 4, 4, 2, 1),
            self._block(features_d * 4, features_d * 8, 4, 2, 1),
            nn.Conv2d(features_d * 8, 1, 4, 2, 0),
        )

    def _block(self, in_channels, out_channels, kernel_size, stride, padding):
        return nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size, stride, padding, bias=False),
            nn.InstanceNorm2d(out_channels, affine=True), # Better for GP
            nn.LeakyReLU(0.2),
        )

    def forward(self, x):
        return self.critic(x)

# --- 2. The Generator (Same structure, SiLU/ReLU fine-tuning) ---
class Generator(nn.Module):
    def __init__(self, z_dim, channels_img, features_g):
        super(Generator, self).__init__()
        self.gen = nn.Sequential(
            self._block(z_dim, features_g * 16, 4, 1, 0),
            self._block(features_g * 16, features_g * 8, 4, 2, 1),
            self._block(features_g * 8, features_g * 4, 4, 2, 1),
            self._block(features_g * 4, features_g * 2, 4, 2, 1),
            nn.ConvTranspose2d(features_g * 2, channels_img, 4, 2, 1),
            nn.Tanh(),
        )

    def _block(self, in_channels, out_channels, kernel_size, stride, padding):
        return nn.Sequential(
            nn.ConvTranspose2d(in_channels, out_channels, kernel_size, stride, padding, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(),
        )

    def forward(self, x):
        return self.gen(x)

# --- 3. Gradient Penalty Function ---
def gradient_penalty(critic, real, fake, device="cpu"):
    BATCH_SIZE, C, H, W = real.shape
    alpha = torch.rand((BATCH_SIZE, 1, 1, 1)).repeat(1, C, H, W).to(device)
    interpolated_images = real * alpha + fake * (1 - alpha)

    # Calculate critic scores
    mixed_scores = critic(interpolated_images)

    # Take the gradient of the scores with respect to the images
    gradient = torch.autograd.grad(
        inputs=interpolated_images,
        outputs=mixed_scores,
        grad_outputs=torch.ones_like(mixed_scores),
        create_graph=True,
        retain_graph=True,
    )[0]
    gradient = gradient.view(gradient.shape[0], -1)
    gradient_norm = gradient.norm(2, dim=1)
    gradient_penalty = torch.mean((gradient_norm - 1) ** 2)
    return gradient_penalty

# --- 4. Initialization & Setup ---
dataset = torchvision.datasets.MNIST(root="dataset/", transform=transforms.Compose([
    transforms.Resize(IMAGE_SIZE), transforms.ToTensor(), transforms.Normalize([0.5], [0.5]),
]), download=True)
loader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True)

gen = Generator(Z_DIM, CHANNELS_IMG, FEATURES_GEN).to(device)
critic = Critic(CHANNELS_IMG, FEATURES_CRITIC).to(device)
opt_gen = optim.Adam(gen.parameters(), lr=LEARNING_RATE, betas=(0.0, 0.9))
opt_critic = optim.Adam(critic.parameters(), lr=LEARNING_RATE, betas=(0.0, 0.9))

# --- 5. Training Loop ---
for epoch in range(NUM_EPOCHS):
    for batch_idx, (real, _) in enumerate(loader):
        real = real.to(device)
        cur_batch_size = real.shape[0]

        for _ in range(CRITIC_ITERATIONS):
            noise = torch.randn(cur_batch_size, Z_DIM, 1, 1).to(device)
            fake = gen(noise)
            critic_real = critic(real).reshape(-1)
            critic_fake = critic(fake).reshape(-1)
            gp = gradient_penalty(critic, real, fake, device=device)
            loss_critic = (
                -(torch.mean(critic_real) - torch.mean(critic_fake)) + LAMBDA_GP * gp
            )
            critic.zero_grad()
            loss_critic.backward(retain_graph=True)
            opt_critic.step()

        gen_fake = critic(fake).reshape(-1)
        loss_gen = -torch.mean(gen_fake)
        gen.zero_grad()
        loss_gen.backward()
        opt_gen.step()

        if batch_idx % 100 == 0:
            print(f"Epoch [{epoch}/{NUM_EPOCHS}] Batch {batch_idx}/{len(loader)} Loss C: {loss_critic:.4f} Loss G: {loss_gen:.4f}")

# Generate and Plot
gen.eval()
with torch.no_grad():
    noise = torch.randn(64, Z_DIM, 1, 1).to(device)
    fake = gen(noise)
    plt.figure(figsize=(8, 8))
    plt.imshow(vutils.make_grid(fake[:64], normalize=True).cpu().permute(1, 2, 0))
    plt.show()
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 18.0MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 480kB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 4.48MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 8.66MB/s]
# Epoch [0/30] Batch 0/938 Loss C: -10.1572 Loss G: 4.6447
# Epoch [0/30] Batch 100/938 Loss C: -37.1564 Loss G: 32.7749
# Epoch [0/30] Batch 200/938 Loss C: -36.9139 Loss G: 32.4468
# Epoch [0/30] Batch 300/938 Loss C: -39.9147 Loss G: 36.6446
# Epoch [0/30] Batch 400/938 Loss C: -38.3385 Loss G: 36.8758
# Epoch [0/30] Batch 500/938 Loss C: -40.0897 Loss G: 33.9241
# Epoch [0/30] Batch 600/938 Loss C: -40.7896 Loss G: 38.0938
# Epoch [0/30] Batch 700/938 Loss C: -39.1623 Loss G: 37.5389
# Epoch [0/30] Batch 800/938 Loss C: -39.9531 Loss G: 40.1080
# Epoch [0/30] Batch 900/938 Loss C: -42.8405 Loss G: 42.4708
# Epoch [1/30] Batch 0/938 Loss C: -43.9513 Loss G: 41.7358
# Epoch [1/30] Batch 100/938 Loss C: -41.0275 Loss G: 39.9390
# Epoch [1/30] Batch 200/938 Loss C: -40.6538 Loss G: 42.1193
# Epoch [1/30] Batch 300/938 Loss C: -44.7486 Loss G: 42.1734
# Epoch [1/30] Batch 400/938 Loss C: -42.8009 Loss G: 44.2096
# Epoch [1/30] Batch 500/938 Loss C: -41.5875 Loss G: 44.0035
# Epoch [1/30] Batch 600/938 Loss C: -43.2145 Loss G: 39.8623
# Epoch [1/30] Batch 700/938 Loss C: -42.6140 Loss G: 43.9115
# Epoch [1/30] Batch 800/938 Loss C: -7.9972 Loss G: 35.6687
# Epoch [1/30] Batch 900/938 Loss C: -9.2272 Loss G: 31.5286
# Epoch [2/30] Batch 0/938 Loss C: -11.3093 Loss G: 33.6150
# Epoch [2/30] Batch 100/938 Loss C: -10.1352 Loss G: 30.9813
# Epoch [2/30] Batch 200/938 Loss C: -9.8266 Loss G: 25.4196
# Epoch [2/30] Batch 300/938 Loss C: -8.9798 Loss G: 30.1235
# Epoch [2/30] Batch 400/938 Loss C: -11.5590 Loss G: 24.2861
# Epoch [2/30] Batch 500/938 Loss C: -10.7117 Loss G: 28.0225
# Epoch [2/30] Batch 600/938 Loss C: -9.8744 Loss G: 17.9458
# Epoch [2/30] Batch 700/938 Loss C: -9.1353 Loss G: 30.0977
# Epoch [2/30] Batch 800/938 Loss C: -11.5826 Loss G: 29.6594
# Epoch [2/30] Batch 900/938 Loss C: -10.8423 Loss G: 25.6005
# Epoch [3/30] Batch 0/938 Loss C: -7.6279 Loss G: 34.4945
# Epoch [3/30] Batch 100/938 Loss C: -10.4448 Loss G: 30.7352
# Epoch [3/30] Batch 200/938 Loss C: -9.5113 Loss G: 25.7314
# Epoch [3/30] Batch 300/938 Loss C: -10.8712 Loss G: 27.1331
# Epoch [3/30] Batch 400/938 Loss C: -10.4374 Loss G: 29.1133
# Epoch [3/30] Batch 500/938 Loss C: -7.6109 Loss G: 29.0360
# Epoch [3/30] Batch 600/938 Loss C: -9.8568 Loss G: 28.4636
# Epoch [3/30] Batch 700/938 Loss C: -9.4569 Loss G: 27.2272
# Epoch [3/30] Batch 800/938 Loss C: -9.9471 Loss G: 33.0300
# Epoch [3/30] Batch 900/938 Loss C: -9.0593 Loss G: 32.3842
# Epoch [4/30] Batch 0/938 Loss C: -9.0797 Loss G: 27.0997
# Epoch [4/30] Batch 100/938 Loss C: -6.8546 Loss G: 22.5380
# Epoch [4/30] Batch 200/938 Loss C: -9.6923 Loss G: 36.9843
# Epoch [4/30] Batch 300/938 Loss C: -9.3702 Loss G: 33.9924
# Epoch [4/30] Batch 400/938 Loss C: -7.5048 Loss G: 26.4272
# Epoch [4/30] Batch 500/938 Loss C: -10.7285 Loss G: 30.6606
# Epoch [4/30] Batch 600/938 Loss C: -8.9066 Loss G: 28.0783
# Epoch [4/30] Batch 700/938 Loss C: -8.5236 Loss G: 26.9865
# Epoch [4/30] Batch 800/938 Loss C: -8.2842 Loss G: 24.8288
# Epoch [4/30] Batch 900/938 Loss C: -9.3665 Loss G: 25.7423
# Epoch [5/30] Batch 0/938 Loss C: -5.2579 Loss G: 19.7260
# Epoch [5/30] Batch 100/938 Loss C: -8.8954 Loss G: 23.9260
# Epoch [5/30] Batch 200/938 Loss C: -8.1137 Loss G: 30.3597
# Epoch [5/30] Batch 300/938 Loss C: -7.4323 Loss G: 22.7260
# Epoch [5/30] Batch 400/938 Loss C: -7.9932 Loss G: 20.6523
# Epoch [5/30] Batch 500/938 Loss C: -8.1065 Loss G: 27.6400
# Epoch [5/30] Batch 600/938 Loss C: -7.9448 Loss G: 21.5715
# Epoch [5/30] Batch 700/938 Loss C: -9.5434 Loss G: 27.0131
# Epoch [5/30] Batch 800/938 Loss C: -7.6235 Loss G: 18.7379
# Epoch [5/30] Batch 900/938 Loss C: -7.4330 Loss G: 32.3048
# Epoch [6/30] Batch 0/938 Loss C: -5.4712 Loss G: 22.3811
# Epoch [6/30] Batch 100/938 Loss C: -8.2065 Loss G: 27.8242
# Epoch [6/30] Batch 200/938 Loss C: -6.2415 Loss G: 20.2419
# Epoch [6/30] Batch 300/938 Loss C: -6.8104 Loss G: 23.5820
# Epoch [6/30] Batch 400/938 Loss C: -6.1792 Loss G: 18.6387
# Epoch [6/30] Batch 500/938 Loss C: -6.5237 Loss G: 22.6148
# Epoch [6/30] Batch 600/938 Loss C: -8.8199 Loss G: 21.3405
# Epoch [6/30] Batch 700/938 Loss C: -5.5179 Loss G: 19.9463
# Epoch [6/30] Batch 800/938 Loss C: -8.1207 Loss G: 19.8559
# Epoch [6/30] Batch 900/938 Loss C: -7.9889 Loss G: 27.9499
# Epoch [7/30] Batch 0/938 Loss C: -7.6398 Loss G: 16.9944
# Epoch [7/30] Batch 100/938 Loss C: -4.3949 Loss G: 17.1369
# Epoch [7/30] Batch 200/938 Loss C: -8.0845 Loss G: 15.7467
# Epoch [7/30] Batch 300/938 Loss C: -7.4653 Loss G: 20.4554
# Epoch [7/30] Batch 400/938 Loss C: -6.8493 Loss G: 15.0745
# Epoch [7/30] Batch 500/938 Loss C: -6.4862 Loss G: 15.0819
# Epoch [7/30] Batch 600/938 Loss C: -7.6080 Loss G: 18.5486
# Epoch [7/30] Batch 700/938 Loss C: -5.7338 Loss G: 9.6914
# Epoch [7/30] Batch 800/938 Loss C: -7.5273 Loss G: 18.4155
# Epoch [7/30] Batch 900/938 Loss C: -6.4957 Loss G: 16.9626
# Epoch [8/30] Batch 0/938 Loss C: -7.8491 Loss G: 12.2451
# Epoch [8/30] Batch 100/938 Loss C: -5.7147 Loss G: 12.0541
# Epoch [8/30] Batch 200/938 Loss C: -7.3849 Loss G: 14.4674
# Epoch [8/30] Batch 300/938 Loss C: -8.1260 Loss G: 13.4167
# Epoch [8/30] Batch 400/938 Loss C: -7.7388 Loss G: 14.1902
# Epoch [8/30] Batch 500/938 Loss C: -8.3170 Loss G: 9.6156
# Epoch [8/30] Batch 600/938 Loss C: -6.5954 Loss G: 12.7903
# Epoch [8/30] Batch 700/938 Loss C: -5.6513 Loss G: 9.4231
# Epoch [8/30] Batch 800/938 Loss C: -7.1167 Loss G: 6.8545
# Epoch [8/30] Batch 900/938 Loss C: -7.7239 Loss G: 8.1900
# Epoch [9/30] Batch 0/938 Loss C: -5.8019 Loss G: 12.0142
# Epoch [9/30] Batch 100/938 Loss C: -6.2367 Loss G: 8.7121
# Epoch [9/30] Batch 200/938 Loss C: -6.2499 Loss G: 6.8297
# Epoch [9/30] Batch 300/938 Loss C: -6.8272 Loss G: 3.2991
# Epoch [9/30] Batch 400/938 Loss C: -7.1291 Loss G: 10.2862
# Epoch [9/30] Batch 500/938 Loss C: -5.8770 Loss G: 6.5359
# Epoch [9/30] Batch 600/938 Loss C: -6.8022 Loss G: 3.4123
# Epoch [9/30] Batch 700/938 Loss C: -5.9223 Loss G: 0.2123
# Epoch [9/30] Batch 800/938 Loss C: -6.7803 Loss G: 2.9934
# Epoch [9/30] Batch 900/938 Loss C: -7.5506 Loss G: 4.7584
# Epoch [10/30] Batch 0/938 Loss C: -3.7262 Loss G: 2.6547
# Epoch [10/30] Batch 100/938 Loss C: -6.1654 Loss G: -0.1635
# Epoch [10/30] Batch 200/938 Loss C: -6.7114 Loss G: -1.5803
# Epoch [10/30] Batch 300/938 Loss C: -5.0362 Loss G: 1.5682
# Epoch [10/30] Batch 400/938 Loss C: -8.0479 Loss G: 3.6365
# Epoch [10/30] Batch 500/938 Loss C: -5.3702 Loss G: -2.1937
# Epoch [10/30] Batch 600/938 Loss C: -4.5448 Loss G: -3.0747
# Epoch [10/30] Batch 700/938 Loss C: -6.1495 Loss G: -2.7102
# Epoch [10/30] Batch 800/938 Loss C: -4.8743 Loss G: -0.4180
# Epoch [10/30] Batch 900/938 Loss C: -5.3114 Loss G: -2.7215
# Epoch [11/30] Batch 0/938 Loss C: -7.5595 Loss G: -0.6025
# Epoch [11/30] Batch 100/938 Loss C: -6.9936 Loss G: 0.5905
# Epoch [11/30] Batch 200/938 Loss C: -6.7791 Loss G: -2.3858
# Epoch [11/30] Batch 300/938 Loss C: -7.6283 Loss G: 0.6365
# Epoch [11/30] Batch 400/938 Loss C: -8.6544 Loss G: -2.7141
# Epoch [11/30] Batch 500/938 Loss C: -6.5655 Loss G: -1.9229
# Epoch [11/30] Batch 600/938 Loss C: -7.1552 Loss G: -6.1022
# Epoch [11/30] Batch 700/938 Loss C: -6.5825 Loss G: -5.0505
# Epoch [11/30] Batch 800/938 Loss C: -4.3150 Loss G: -4.5666
# Epoch [11/30] Batch 900/938 Loss C: -7.1848 Loss G: -3.8939
# Epoch [12/30] Batch 0/938 Loss C: -6.4492 Loss G: -8.9560
# Epoch [12/30] Batch 100/938 Loss C: -7.0092 Loss G: -4.5080
# Epoch [12/30] Batch 200/938 Loss C: -6.0416 Loss G: -7.0462
# Epoch [12/30] Batch 300/938 Loss C: -5.6436 Loss G: -8.1057
# Epoch [12/30] Batch 400/938 Loss C: -6.9660 Loss G: -8.4775
# Epoch [12/30] Batch 500/938 Loss C: -7.2204 Loss G: -13.9523
# Epoch [12/30] Batch 600/938 Loss C: -6.4289 Loss G: -11.4609
# Epoch [12/30] Batch 700/938 Loss C: -4.4353 Loss G: -15.8332
# Epoch [12/30] Batch 800/938 Loss C: -7.7685 Loss G: -14.4550
# Epoch [12/30] Batch 900/938 Loss C: -7.3691 Loss G: -14.2031
# Epoch [13/30] Batch 0/938 Loss C: -6.7161 Loss G: -17.5277
# Epoch [13/30] Batch 100/938 Loss C: -7.1133 Loss G: -11.9148
# Epoch [13/30] Batch 200/938 Loss C: -7.0466 Loss G: -17.5667
# Epoch [13/30] Batch 300/938 Loss C: -6.3983 Loss G: -16.1343
# Epoch [13/30] Batch 400/938 Loss C: -7.1147 Loss G: -19.3051
# Epoch [13/30] Batch 500/938 Loss C: -6.2362 Loss G: -17.2739
# Epoch [13/30] Batch 600/938 Loss C: -6.6093 Loss G: -20.6360
# Epoch [13/30] Batch 700/938 Loss C: -8.3348 Loss G: -15.6106
# Epoch [13/30] Batch 800/938 Loss C: -5.7065 Loss G: -16.5847
# Epoch [13/30] Batch 900/938 Loss C: -6.4626 Loss G: -23.0167
# Epoch [14/30] Batch 0/938 Loss C: -5.1705 Loss G: -17.5755
# Epoch [14/30] Batch 100/938 Loss C: -6.9980 Loss G: -20.4126
# Epoch [14/30] Batch 200/938 Loss C: -6.3678 Loss G: -18.6401
# Epoch [14/30] Batch 300/938 Loss C: -5.1317 Loss G: -19.4821
# Epoch [14/30] Batch 400/938 Loss C: -5.3767 Loss G: -16.5351
# Epoch [14/30] Batch 500/938 Loss C: -5.6911 Loss G: -21.9501
# Epoch [14/30] Batch 600/938 Loss C: -6.4698 Loss G: -19.4703
# Epoch [14/30] Batch 700/938 Loss C: -5.3968 Loss G: -19.7338
# Epoch [14/30] Batch 800/938 Loss C: -7.2359 Loss G: -19.0093
# Epoch [14/30] Batch 900/938 Loss C: -5.9787 Loss G: -23.6290
# Epoch [15/30] Batch 0/938 Loss C: -7.0227 Loss G: -24.5581
# Epoch [15/30] Batch 100/938 Loss C: -6.4770 Loss G: -21.7163
# Epoch [15/30] Batch 200/938 Loss C: -5.3199 Loss G: -30.3830
# Epoch [15/30] Batch 300/938 Loss C: -8.5500 Loss G: -26.1394
# Epoch [15/30] Batch 400/938 Loss C: -6.3886 Loss G: -24.8285
# Epoch [15/30] Batch 500/938 Loss C: -6.6062 Loss G: -28.3334
# Epoch [15/30] Batch 600/938 Loss C: -6.8298 Loss G: -21.3628
# Epoch [15/30] Batch 700/938 Loss C: -4.4288 Loss G: -25.7799
# Epoch [15/30] Batch 800/938 Loss C: -7.0462 Loss G: -26.5666
# Epoch [15/30] Batch 900/938 Loss C: -6.3297 Loss G: -27.6769
# Epoch [16/30] Batch 0/938 Loss C: -6.6252 Loss G: -30.8736
# Epoch [16/30] Batch 100/938 Loss C: -6.0022 Loss G: -31.8878
# Epoch [16/30] Batch 200/938 Loss C: -7.1415 Loss G: -30.1616
# Epoch [16/30] Batch 300/938 Loss C: -5.9363 Loss G: -34.1085
# Epoch [16/30] Batch 400/938 Loss C: -7.1718 Loss G: -28.4697
# Epoch [16/30] Batch 500/938 Loss C: -6.7019 Loss G: -32.1573
# Epoch [16/30] Batch 600/938 Loss C: -6.2984 Loss G: -34.0461
# Epoch [16/30] Batch 700/938 Loss C: -6.2407 Loss G: -35.3796
# Epoch [16/30] Batch 800/938 Loss C: -5.2959 Loss G: -32.0613
# Epoch [16/30] Batch 900/938 Loss C: -4.5790 Loss G: -35.6741
# Epoch [17/30] Batch 0/938 Loss C: -7.1224 Loss G: -34.0110
# Epoch [17/30] Batch 100/938 Loss C: -4.8577 Loss G: -32.2618
# Epoch [17/30] Batch 200/938 Loss C: -4.9748 Loss G: -35.8650
# Epoch [17/30] Batch 300/938 Loss C: -6.3856 Loss G: -34.4518
# Epoch [17/30] Batch 400/938 Loss C: -7.4402 Loss G: -35.5978
# Epoch [17/30] Batch 500/938 Loss C: -6.1275 Loss G: -36.3712
# Epoch [17/30] Batch 600/938 Loss C: -6.5176 Loss G: -36.9431
# Epoch [17/30] Batch 700/938 Loss C: -5.0419 Loss G: -38.7822
# Epoch [17/30] Batch 800/938 Loss C: -6.0954 Loss G: -37.4772
# Epoch [17/30] Batch 900/938 Loss C: -4.8874 Loss G: -41.0473
# Epoch [18/30] Batch 0/938 Loss C: -4.2527 Loss G: -38.3656
# Epoch [18/30] Batch 100/938 Loss C: -5.7260 Loss G: -40.7714
# Epoch [18/30] Batch 200/938 Loss C: -5.6555 Loss G: -43.0452
# Epoch [18/30] Batch 300/938 Loss C: -3.9900 Loss G: -44.1412
# Epoch [18/30] Batch 400/938 Loss C: -5.7144 Loss G: -45.4876
# Epoch [18/30] Batch 500/938 Loss C: -6.4610 Loss G: -41.5061
# Epoch [18/30] Batch 600/938 Loss C: -7.0234 Loss G: -44.3521
# Epoch [18/30] Batch 700/938 Loss C: -5.9484 Loss G: -44.4384
# Epoch [18/30] Batch 800/938 Loss C: -4.9199 Loss G: -43.5352
# Epoch [18/30] Batch 900/938 Loss C: -8.2187 Loss G: -44.0356
# Epoch [19/30] Batch 0/938 Loss C: -5.8788 Loss G: -43.0504
